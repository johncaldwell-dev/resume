# %%
import pandas as pd

resume_location = r'C:\Users\jcaldwell\Desktop\Personal\personal_info_background.xlsx'
df = pd.read_excel(resume_location)

# %%
print(df)
# Out:
#   first_name middle_name last_name name_suffix            address      city  \
# 0       John      Melvin  Caldwell          Jr  145 Groves Avenue  Marietta
#
#      state  zipcode      county  phone_name  mobile_phone
# 0  OH-Ohio    45750  Washington         NaN  740-516-7495

# %%
full_name = df['first_name'].str.title() + " " + df['last_name'].str.title()

# %%
print(full_name)
# Out:
# 0    John Caldwell
# dtype: object
